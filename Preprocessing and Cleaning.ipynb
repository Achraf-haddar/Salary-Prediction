# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')
print(df.shape)
df.head()
# Out:
# (250, 14)
#                      Job Title                   Salary Estimate  \
# 0  DOD Data Scientist/Engineer       $94K-$155K (Glassdoor est.)
# 1      Research Data Scientist       $72K-$120K (Glassdoor est.)
# 2           Research Scientist                                -1
# 3    Clinical Lab Scientist/MT  $20-$33 Per Hour(Glassdoor est.)
# 4  Scientist III, Pharma R & D        $27K-$85K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Overview\n\nGuidehouse is a leading management...     3.6
# 1  IAI is looking for a talented research scienti...     3.7
# 2  Job Description:\n\nOur Reston office is seeki...     3.0
# 3  Description\n\nPerforms various routine and co...     3.8
# 4  The Scientist III develops and executes formul...     3.2
#
#                   Company Name            Location  Headquarters  \
# 0              Guidehouse\n3.6  Patuxent River, MD            -1
# ...

# %%
# get salary estimate != -1
df = df[df["Salary Estimate"] != '-1']
print(df.shape)
# Out:
# (237, 14)

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.split('(')[0])
df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.replace('K','').replace('$', ''))
df.head()
# Out:
#                           Job Title Salary Estimate  \
# 0       DOD Data Scientist/Engineer         94-155
# 1           Research Data Scientist         72-120
# 3         Clinical Lab Scientist/MT  20-33 Per Hour
# 4       Scientist III, Pharma R & D          27-85
# 6  Clinical Lab Scientist/MT or MLT  20-32 Per Hour
#
#                                      Job Description  Rating  \
# 0  Overview\n\nGuidehouse is a leading management...     3.6
# 1  IAI is looking for a talented research scienti...     3.7
# 3  Description\n\nPerforms various routine and co...     3.8
# 4  The Scientist III develops and executes formul...     3.2
# 6  Description\n\nPerforms various routine and co...     3.8
#
#                   Company Name            Location  Headquarters  \
# 0              Guidehouse\n3.6  Patuxent River, MD            -1
# 1  Intelligent Automation\n3.7       Rockville, MD            -1
# 3          OSF Healthcare\n3.8          Peoria, IL            -1
# ...

# %%
# Some feature engineering
df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['employer_provided'] = df['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)
df.head()
# Out:
#                           Job Title Salary Estimate  \
# 0       DOD Data Scientist/Engineer         94-155
# 1           Research Data Scientist         72-120
# 3         Clinical Lab Scientist/MT  20-33 Per Hour
# 4       Scientist III, Pharma R & D          27-85
# 6  Clinical Lab Scientist/MT or MLT  20-32 Per Hour
#
#                                      Job Description  Rating  \
# 0  Overview\n\nGuidehouse is a leading management...     3.6
# 1  IAI is looking for a talented research scienti...     3.7
# 3  Description\n\nPerforms various routine and co...     3.8
# 4  The Scientist III develops and executes formul...     3.2
# 6  Description\n\nPerforms various routine and co...     3.8
#
#                   Company Name            Location  Headquarters  \
# 0              Guidehouse\n3.6  Patuxent River, MD            -1
# 1  Intelligent Automation\n3.7       Rockville, MD            -1
# 3          OSF Healthcare\n3.8          Peoria, IL            -1
# ...

# %%
df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: x.lower().replace('per hour','').replace('employer provided slary:',''))
df.head()
# Out:
#                           Job Title Salary Estimate  \
# 0       DOD Data Scientist/Engineer         94-155
# 1           Research Data Scientist         72-120
# 3         Clinical Lab Scientist/MT          20-33
# 4       Scientist III, Pharma R & D          27-85
# 6  Clinical Lab Scientist/MT or MLT          20-32
#
#                                      Job Description  Rating  \
# 0  Overview\n\nGuidehouse is a leading management...     3.6
# 1  IAI is looking for a talented research scienti...     3.7
# 3  Description\n\nPerforms various routine and co...     3.8
# 4  The Scientist III develops and executes formul...     3.2
# 6  Description\n\nPerforms various routine and co...     3.8
#
#                   Company Name            Location  Headquarters  \
# 0              Guidehouse\n3.6  Patuxent River, MD            -1
# 1  Intelligent Automation\n3.7       Rockville, MD            -1
# 3          OSF Healthcare\n3.8          Peoria, IL            -1
# ...

# %%
df['min_salary'] = df['Salary Estimate'].apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = df['Salary Estimate'].apply(lambda x: int(x.split('-')[1]))
df['avg_salary'] = (df['min_salary'] + df['max_salary']) / 2
df.head()
# Out:
#                           Job Title Salary Estimate  \
# 0       DOD Data Scientist/Engineer         94-155
# 1           Research Data Scientist         72-120
# 3         Clinical Lab Scientist/MT          20-33
# 4       Scientist III, Pharma R & D          27-85
# 6  Clinical Lab Scientist/MT or MLT          20-32
#
#                                      Job Description  Rating  \
# 0  Overview\n\nGuidehouse is a leading management...     3.6
# 1  IAI is looking for a talented research scienti...     3.7
# 3  Description\n\nPerforms various routine and co...     3.8
# 4  The Scientist III develops and executes formul...     3.2
# 6  Description\n\nPerforms various routine and co...     3.8
#
#                   Company Name            Location  Headquarters  \
# 0              Guidehouse\n3.6  Patuxent River, MD            -1
# 1  Intelligent Automation\n3.7       Rockville, MD            -1
# 3          OSF Healthcare\n3.8          Peoria, IL            -1
# ...

# %%
# Company name text only
df['company_txt'] = df.apply(lambda x: x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-3], axis=1)
# state field
df['job_state'] = df['Location'].apply(lambda x: '-1' if ',' not in x.lower() else x.split(',')[1])
df['same_state'] = df.apply(lambda x: 1 if x['Location'] == x['Headquarters'] else 0, axis=1)
# age of company
df['age'] = df['Founded'].apply(lambda x: x if x<1 else 2020-x)
# parsing of job description
df['python_yn'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
df['R_yn'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'r-studio' in x.lower() else 0)
df['spark'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
df['aws'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
df.head()
# Out:
#                           Job Title Salary Estimate  \
# 0       DOD Data Scientist/Engineer         94-155
# 1           Research Data Scientist         72-120
# 3         Clinical Lab Scientist/MT          20-33
# 4       Scientist III, Pharma R & D          27-85
# 6  Clinical Lab Scientist/MT or MLT          20-32
#
#                                      Job Description  Rating  \
# 0  Overview\n\nGuidehouse is a leading management...     3.6
# 1  IAI is looking for a talented research scienti...     3.7
# 3  Description\n\nPerforms various routine and co...     3.8
# 4  The Scientist III develops and executes formul...     3.2
# 6  Description\n\nPerforms various routine and co...     3.8
#
#                   Company Name            Location  Headquarters  \
# 0              Guidehouse\n3.6  Patuxent River, MD            -1
# 1  Intelligent Automation\n3.7       Rockville, MD            -1
# 3          OSF Healthcare\n3.8          Peoria, IL            -1
# ...

# %%
df.to_csv('df_clean.csv', index=False)
